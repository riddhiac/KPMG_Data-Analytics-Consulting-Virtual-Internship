# %%
import pandas as pd
import numpy as np

# %%
url = '/Users/riddhi/Documents/DS/KPMG/RIDDHI/Module -1 /KPMG_VI_New_raw_data_update_final.xlsx'
transactions = pd.read_excel(url, sheet_name='Transactions')
customer_demographic = pd.read_excel(url, sheet_name='CustomerDemographic')
customer_add = pd.read_excel(url, sheet_name='CustomerAddress')
new_customer_lists = pd.read_excel(url, sheet_name='NewCustomerList')

# %% [markdown]
# # 1. Exploring the Transactions Dataset

# %%
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %% [markdown]
# The values in the **product_first_sold_date** columns are not correct as it shows everything happening the same day at different times.

# %%
#convert date columns from integer to datetime
transactions['product_first_sold_date'] = pd.to_datetime(transactions['product_first_sold_date'], unit='s')
transactions['product_first_sold_date'].head()
# Out:
# 0   1970-01-01 11:27:25
# 1   1970-01-01 11:35:01
# 2   1970-01-01 10:06:01
# 3   1970-01-01 10:02:25
# 4   1970-01-01 11:43:46
# Name: product_first_sold_date, dtype: datetime64[ns]

# %%
print("Rows : ", transactions.shape[0])
print("Columns : ", transactions.shape[1])
# Out:
# Rows :  20000
# Columns :  13

# %% [markdown]
# #### Exploring Missing Values

# %%
transactions.isna().values.any()
# Out:
# True

# %%
transactions.isna().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
# transactions.dropna(subset=['online_order','brand','product_line','product_class','product_size','standard_cost','product_first_sold_date'],inplace = True)
#    __OR__
# transactions = transactions[-transactions["online_order"].isnull()]
#    __OR__
transactions.dropna(inplace=True)
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
transactions.nunique()
# Out:
# transaction_id             19445
# product_id                   101
# customer_id                 3492
# transaction_date             364
# online_order                   2
# order_status                   2
# brand                          6
# product_line                   4
# product_class                  3
# product_size                   3
# list_price                   100
# standard_cost                103
# product_first_sold_date      100
# dtype: int64

# %% [markdown]
# #### Check for Duplicate Values in Dataset

# %%
transactions[transactions.duplicated()]
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date]
# Index: []

# %%
transactions.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Exploring Columns

# %%
transactions.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
transactions['online_order'].value_counts()
# Out:
# 1.0    9739
# 0.0    9706
# Name: online_order, dtype: int64

# %%
transactions['order_status'].value_counts()
# Out:
# Approved     19273
# Cancelled      172
# Name: order_status, dtype: int64

# %%
transactions['brand'].value_counts()
# Out:
# Solex             4169
# WeareA2B          3245
# Giant Bicycles    3244
# OHM Cycles        2993
# Trek Bicycles     2931
# Norco Bicycles    2863
# Name: brand, dtype: int64

# %%
transactions['product_line'].value_counts()
# Out:
# Standard    13920
# Road         3894
# Touring      1213
# Mountain      418
# Name: product_line, dtype: int64

# %%
transactions['product_class'].value_counts()
# Out:
# medium    13587
# high       2952
# low        2906
# Name: product_class, dtype: int64

# %%
transactions['product_size'].value_counts()
# Out:
# medium    12767
# large      3900
# small      2778
# Name: product_size, dtype: int64

# %%
transactions.describe()
# Out:
#        transaction_id    product_id   customer_id  online_order    list_price  \
# count    19445.000000  19445.000000  19445.000000  19445.000000  19445.000000
# mean      9989.257393     45.797737   1739.467267      0.500849   1107.337193
# std       5779.669087     30.571996   1011.889153      0.500012    582.662400
# min          1.000000      0.000000      1.000000      0.000000     12.010000
# 25%       4976.000000     18.000000    857.000000      0.000000    575.270000
# 50%       9985.000000     45.000000   1741.000000      1.000000   1163.890000
# 75%      14997.000000     72.000000   2615.000000      1.000000   1635.300000
# max      20000.000000    100.000000   5034.000000      1.000000   2091.470000
#
#        standard_cost
# count   19445.000000
# mean      555.585260
# std       405.596541
# min         7.210000
# 25%       215.140000
# 50%       507.580000
# 75%       795.100000
# max      1759.850000

# %% [markdown]
# #### All the columns appear to have consistent and correct information.

# %%
#add "profit" column. Formulae = List price - Standard Cost

transactions["profit"] = transactions["list_price"] - transactions["standard_cost"]
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date   profit
# ...

# %% [markdown]
# #### Cleaning the data
# Drop all the entries without online order

# %%
transactions.drop(transactions[transactions['online_order'] == False].index, inplace=True)

# %%
transactions
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 1                   2           3         3120       2017-05-21           1.0
# 4                   5          78          787       2017-10-01           1.0
# 5                   6          25         2339       2017-03-08           1.0
# 6                   7          22         1542       2017-04-21           1.0
# 9                  10          12         3262       2017-08-30           1.0
# ...               ...         ...          ...              ...           ...
# 19994           19995           9          718       2017-05-13           1.0
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
filepath = '/Users/riddhi/Documents/DS/KPMG/RIDDHI/Module -1 /Transactions.xlsx'
transactions.to_excel(filepath,index = False)

# %% [markdown]
# # 2. Exploring New Customer List Dataset

# %%
new_customer_lists.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
new_customer_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
new_customer_lists.drop(['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'],axis=1, inplace=True)
new_customer_lists.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
new_customer_lists.nunique()
# Out:
# first_name                              940
# last_name                               961
# gender                                    3
# past_3_years_bike_related_purchases     100
# DOB                                     958
# job_title                               184
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        1
# owns_car                                  2
# tenure                                   23
# address                                1000
# postcode                                522
# state                                     3
# country                                   1
# property_valuation                       12
# Rank                                    324
# Value                                   324
# dtype: int64

# %%
new_customer_lists['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
new_customer_lists.drop(new_customer_lists[new_customer_lists['gender'] == 'U'].index, inplace=True)
new_customer_lists['gender'].value_counts()
# Out:
# Female    513
# Male      470
# Name: gender, dtype: int64

# %% [markdown]
# #### Exploring Missing Values

# %%
new_customer_lists.isna().values.any()
# Out:
# True

# %%
new_customer_lists.isna().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                              105
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
new_customer_lists.dropna(subset = ['job_title','job_industry_category'],inplace=True)

# %%
new_customer_lists.duplicated().sum()
# Out:
# 0

# %%
new_customer_lists[new_customer_lists.duplicated()]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, Rank, Value]
# Index: []

# %%
new_customer_lists['year'] = pd.DatetimeIndex(new_customer_lists['DOB']).year
new_customer_lists['month'] = pd.DatetimeIndex(new_customer_lists['DOB']).month
new_customer_lists['age'] = 2021 - new_customer_lists['year']

new_customer_lists.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...              address  \
# 0      Mass Customer                  N      Yes  ...     45 Shopko Center
# ...

# %%
new_customer_lists.drop(['DOB'],axis=1,inplace=True)

# %%
new_customer_lists[new_customer_lists.age >= 100]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, Rank, Value, year, month, age]
# Index: []

# %%
new_customer_lists.describe()
# Out:
#        past_3_years_bike_related_purchases      tenure     postcode  \
# count                           735.000000  735.000000   735.000000
# mean                             49.665306   11.378231  3030.327891
# std                              27.592640    5.003657   851.485695
# min                               0.000000    1.000000  2000.000000
# 25%                              27.000000    7.000000  2211.500000
# 50%                              50.000000   11.000000  3012.000000
# 75%                              71.000000   15.000000  3855.000000
# max                              99.000000   22.000000  4879.000000
#
#        property_valuation         Rank       Value         year       month  \
# count          735.000000   735.000000  735.000000   735.000000  735.000000
# mean             7.380952   507.887075    0.873770  1971.405442    6.621769
# std              2.837404   289.259266    0.295606    16.997643    3.505319
# ...

# %% [markdown]
# #### Exploring Columns

# %%
new_customer_lists.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value', 'year', 'month', 'age'],
#       dtype='object')

# %%
new_customer_lists['state'].value_counts()
# Out:
# NSW    364
# VIC    200
# QLD    171
# Name: state, dtype: int64

# %%
new_customer_lists['state'] = new_customer_lists['state'].replace('QLD','Queensland')
new_customer_lists['state'] = new_customer_lists['state'].replace('NSW','New South Wales')
new_customer_lists['state'] = new_customer_lists['state'].replace('VIC', 'Victoria')
new_customer_lists.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#                     job_title job_industry_category     wealth_segment  \
# 0             General Manager         Manufacturing      Mass Customer
# 1         Structural Engineer              Property      Mass Customer
# 2      Senior Cost Accountant    Financial Services  Affluent Customer
# 3  Account Representative III         Manufacturing  Affluent Customer
# 4           Financial Analyst    Financial Services  Affluent Customer
#
#   deceased_indicator owns_car  tenure              address  postcode  \
# ...

# %%
new_customer_lists['state'].value_counts()
# Out:
# New South Wales    364
# Victoria           200
# Queensland         171
# Name: state, dtype: int64

# %%
new_customer_lists['gender'].value_counts()
# Out:
# Female    380
# Male      355
# Name: gender, dtype: int64

# %%
new_customer_lists['job_title'].value_counts()
# Out:
# Associate Professor          12
# Cost Accountant              12
# Software Consultant          12
# Environmental Tech           12
# Junior Executive             11
#                              ..
# Media Manager III             1
# Accounting Assistant IV       1
# Systems Administrator II      1
# Database Administrator IV     1
# Database Administrator I      1
# Name: job_title, Length: 178, dtype: int64

# %%
new_customer_lists['job_industry_category'].value_counts()
# Out:
# Financial Services    187
# Manufacturing         175
# Health                138
# Retail                 73
# Property               51
# Entertainment          34
# IT                     30
# Argiculture            24
# Telecommunications     23
# Name: job_industry_category, dtype: int64

# %%
new_customer_lists['wealth_segment'].value_counts()
# Out:
# Mass Customer        369
# High Net Worth       184
# Affluent Customer    182
# Name: wealth_segment, dtype: int64

# %%
new_customer_lists['deceased_indicator'].value_counts()
# Out:
# N    735
# Name: deceased_indicator, dtype: int64

# %%
new_customer_lists['tenure'].value_counts()
# Out:
# 9     58
# 11    53
# 13    48
# 7     47
# 12    47
# 10    46
# 17    46
# 16    43
# 5     42
# 8     42
# 15    42
# 14    36
# 6     33
# 4     29
# 18    25
# 19    22
# 20    17
# 21    16
# 3     15
# 2     11
# 22     9
# 1      8
# Name: tenure, dtype: int64

# %%
new_customer_lists['country'].value_counts()
# Out:
# Australia    735
# Name: country, dtype: int64

# %%
new_customer_lists['Rank'].value_counts()
# Out:
# 760     10
# 259     10
# 536      8
# 700      7
# 676      6
#         ..
# 324      1
# 724      1
# 722      1
# 370      1
# 1000     1
# Name: Rank, Length: 292, dtype: int64

# %%
filepath = '/Users/riddhi/Documents/DS/KPMG/RIDDHI/Module -1 /NewCustomerList.xlsx'
new_customer_lists.to_excel(filepath,index = False)

# %% [markdown]
# # 3. Exploring Customer Demographic Data Set¶

# %%
customer_demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
customer_demographic.drop(['default'],axis=1,inplace=True)

# %%
print("Rows: ", customer_demographic.shape[0])
print("Columns: ", customer_demographic.shape[1])
# Out:
# Rows:  4000
# Columns:  12

# %%
customer_demographic.nunique()
# Out:
# customer_id                            4000
# first_name                             3139
# last_name                              3725
# gender                                    6
# past_3_years_bike_related_purchases     100
# DOB                                    3448
# job_title                               195
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        2
# owns_car                                  2
# tenure                                   22
# dtype: int64

# %%
customer_demographic.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
customer_demographic.isna().values.any()
# Out:
# True

# %%
customer_demographic.isna().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
customer_demographic.dropna(subset = ['job_title','job_industry_category','tenure'])
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp  Female
# 1               2        Eli    Bockman    Male
# 2               3      Arlin     Dearle    Male
# 8               9       Mala       Lind  Female
# 9              10   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992         3993       Andi    Dumelow  Female
# 3993         3994    Stephie      Byars  Female
# 3994         3995      Rusty     Iapico    Male
# 3995         3996    Rosalia   Halgarth  Female
# 3996         3997     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases  \
# 0                                      93
# 1                                      81
# 2                                      61
# 8                                      97
# 9                                      49
# ...                                   ...
# 3992                                    6
# ...

# %%
customer_demographic['gender'].value_counts()
# customer_demographic.gender.unique()
# Out:
# Female    1481
# Male      1381
# U            1
# F            1
# Femal        1
# Name: gender, dtype: int64

# %%
customer_demographic['gender'] = customer_demographic['gender'].replace('F','Female')
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 8                                   97 1973-03-10
# 9                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 8  Business Systems Development Analyst           Argiculture
# 9               Senior Quality Engineer    Financial Services
#
# ...

# %%
customer_demographic['gender'] = customer_demographic['gender'].replace('U','Unspecified')
customer_demographic['gender'] = customer_demographic['gender'].replace('Femal','Female')
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 8                                   97 1973-03-10
# 9                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 8  Business Systems Development Analyst           Argiculture
# 9               Senior Quality Engineer    Financial Services
#
# ...

# %%
customer_demographic.gender.nunique()
# Out:
# 3

# %%
customer_demographic.gender.unique()
# Out:
# array(['Female', 'Male', 'Unspecified'], dtype=object)

# %%
customer_demographic['year'] = pd.DatetimeIndex(customer_demographic['DOB']).year
customer_demographic['month'] = pd.DatetimeIndex(customer_demographic['DOB']).month
customer_demographic['age'] = 2021 - customer_demographic['year']
customer_demographic.drop(['DOB'],axis=1,inplace=True)
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases                             job_title  \
# 0                                   93                   Executive Secretary
# 1                                   81                Administrative Officer
# 2                                   61                    Recruiting Manager
# 8                                   97  Business Systems Development Analyst
# 9                                   49               Senior Quality Engineer
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                  N      Yes
# 1    Financial Services      Mass Customer                  N      Yes
# ...

# %%
customer_demographic[customer_demographic.age > 100]
# Out:
#     customer_id first_name last_name       gender  \
# 33           34   Jephthah  Bachmann  Unspecified
#
#     past_3_years_bike_related_purchases        job_title  \
# 33                                   59  Legal Assistant
#
#    job_industry_category     wealth_segment deceased_indicator owns_car  \
# 33                    IT  Affluent Customer                  N       No
#
#     tenure  year  month  age
# 33    20.0  1843     12  178

# %%
customer_demographic.drop(33,axis=0,inplace=True)

# %%
customer_demographic[customer_demographic.age > 100]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, past_3_years_bike_related_purchases, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, year, month, age]
# Index: []

# %%
customer_demographic.shape
# Out:
# (2864, 14)

# %%
customer_demographic.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'year', 'month', 'age'],
#       dtype='object')

# %%
customer_demographic['gender'].value_counts()
# Out:
# Female    1483
# Male      1381
# Name: gender, dtype: int64

# %%
customer_demographic['job_title'].value_counts()
# Out:
# Social Worker                   42
# Sales Representative            38
# Chemical Engineer               37
# Dental Hygienist                37
# Cost Accountant                 36
#                                 ..
# Research Assistant III           2
# Accounting Assistant IV          2
# Human Resources Assistant IV     2
# Developer I                      1
# Database Administrator II        1
# Name: job_title, Length: 195, dtype: int64

# %%
customer_demographic['job_industry_category'].value_counts()
# Out:
# Manufacturing         695
# Financial Services    682
# Health                543
# Retail                305
# Property              231
# IT                    126
# Entertainment         122
# Argiculture            99
# Telecommunications     61
# Name: job_industry_category, dtype: int64

# %%
customer_demographic['wealth_segment'].value_counts()
# Out:
# Mass Customer        1427
# High Net Worth        734
# Affluent Customer     703
# Name: wealth_segment, dtype: int64

# %%
customer_demographic['deceased_indicator'].value_counts()
# Out:
# N    2862
# Y       2
# Name: deceased_indicator, dtype: int64

# %%
customer_demographic['owns_car'].value_counts()
# Out:
# Yes    1463
# No     1401
# Name: owns_car, dtype: int64

# %%
customer_demographic['tenure'].value_counts()
# Out:
# 5.0     167
# 7.0     166
# 16.0    164
# 12.0    161
# 10.0    159
# 11.0    159
# 8.0     156
# 18.0    155
# 14.0    150
# 9.0     149
# 6.0     142
# 13.0    138
# 4.0     133
# 17.0    124
# 1.0     122
# 3.0     120
# 19.0    118
# 15.0    114
# 2.0     110
# 20.0     71
# 21.0     44
# 22.0     42
# Name: tenure, dtype: int64

# %%
customer_demographic['year'].value_counts()
# Out:
# 1978    166
# 1977    148
# 1974    119
# 1976    109
# 1979     93
# 1975     91
# 1973     89
# 1986     86
# 1980     80
# 1959     68
# 1985     66
# 1964     65
# 1981     63
# 1998     61
# 1971     61
# 1992     61
# 1988     60
# 1994     60
# 1969     58
# 1995     56
# 1997     55
# 1989     55
# 1967     54
# 1965     54
# 1987     53
# 1968     51
# 1962     50
# 1966     49
# 1999     48
# 1956     48
# 1996     48
# 1993     46
# 1957     45
# 1963     44
# 1955     42
# 1961     41
# 1990     40
# 1960     39
# 1972     38
# 1970     38
# 1954     37
# 1958     34
# 1991     32
# 1983     32
# 2000     30
# 2001     27
# 1984     25
# 1982     24
# 1953     18
# 2002      3
# 1944      1
# 1943      1
# 1931      1
# 1935      1
# Name: year, dtype: int64

# %%
customer_demographic
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp  Female
# 1               2        Eli    Bockman    Male
# 2               3      Arlin     Dearle    Male
# 8               9       Mala       Lind  Female
# 9              10   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992         3993       Andi    Dumelow  Female
# 3993         3994    Stephie      Byars  Female
# 3994         3995      Rusty     Iapico    Male
# 3995         3996    Rosalia   Halgarth  Female
# 3996         3997     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases  \
# 0                                      93
# 1                                      81
# 2                                      61
# 8                                      97
# 9                                      49
# ...                                   ...
# 3992                                    6
# ...

# %%
filepath = '/Users/riddhi/Documents/DS/KPMG/RIDDHI/Module -1 /CustomerDemographics.xlsx'
customer_demographic.to_excel(filepath,index = False)

# %% [markdown]
# # 4. Exploring Customer Address Dataset

# %%
customer_add.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
customer_add.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
customer_add.describe()
# Out:
#        customer_id     postcode  property_valuation
# count  3999.000000  3999.000000         3999.000000
# mean   2003.987997  2985.755939            7.514379
# std    1154.576912   844.878364            2.824663
# min       1.000000  2000.000000            1.000000
# 25%    1004.500000  2200.000000            6.000000
# 50%    2004.000000  2768.000000            8.000000
# 75%    3003.500000  3750.000000           10.000000
# max    4003.000000  4883.000000           12.000000

# %%
customer_add.nunique()
# Out:
# customer_id           3999
# address               3996
# postcode               873
# state                    5
# country                  1
# property_valuation      12
# dtype: int64

# %%
customer_add.isna().values.any()
# Out:
# False

# %%
print("Rows: ", customer_add.shape[0])
print("Columns: ", customer_add.shape[1])
# Out:
# Rows:  3999
# Columns:  6

# %%
customer_add.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
customer_add['state'] = customer_add['state'].replace('QLD','Queensland')
customer_add['state'] = customer_add['state'].replace('NSW','New South Wales')
customer_add['state'] = customer_add['state'].replace('VIC','Victoria')
customer_add.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211       Queensland  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216         Victoria  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
customer_add['state'].value_counts()
# Out:
# New South Wales    2140
# Victoria           1021
# Queensland          838
# Name: state, dtype: int64

# %%
customer_add['country'].value_counts()
# Out:
# Australia    3999
# Name: country, dtype: int64

# %%
customer_add['postcode'].value_counts()
# Out:
# 2170    31
# 2145    30
# 2155    30
# 2153    29
# 3977    26
#         ..
# 3331     1
# 3036     1
# 3321     1
# 3305     1
# 2143     1
# Name: postcode, Length: 873, dtype: int64

# %%
customer_add['property_valuation'].value_counts()
# Out:
# 9     647
# 8     646
# 10    577
# 7     493
# 11    281
# 6     238
# 5     225
# 4     214
# 12    195
# 3     186
# 1     154
# 2     143
# Name: property_valuation, dtype: int64

# %%
filepath = '/Users/riddhi/Documents/DS/KPMG/RIDDHI/Module -1 /CustomerAddress.xlsx'
customer_add.to_excel(filepath,index = False)

# %%
solution_file = '/Users/riddhi/Documents/DS/KPMG/RIDDHI/Module -1 /KPMG_After_Cleaning.xlsx'

writer = pd.ExcelWriter(solution_file, engine='xlsxwriter')

transactions.to_excel(writer, sheet_name = "Transactions",index=False)
new_customer_lists.to_excel(writer, sheet_name = "NewCustomerList",index=False)
customer_demographic.to_excel(writer, sheet_name = "CustomerDemographic",index=False)
customer_add.to_excel(writer, sheet_name = "CustomerAddress",index=False)

writer.save()

# %% [markdown]
# #### We can see that the 3 tables : the 'Customer Demographic' Table , the 'New Customer Lists' Table and the 'Customer Address' Table are relevant to each other, so it would be more meaningful to combine these tables and view them as one.

# %%
customer_demographic['customer_id'].iloc[-1] #return total number of rows of customer_id columns
# Out:
# 3997

# %%
#  add 'Customer Id' column to new_customer_lists
new_customer_lists.insert(0,'customer_id',range(3998,3998 + len(new_customer_lists)))

# %%
new_customer_lists.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0         3998    Chickie    Brister    Male
# 1         3999      Morly     Genery    Male
# 2         4000    Ardelis  Forrester  Female
# 3         4001     Lucine      Stutt  Female
# 4         4002    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases                   job_title  \
# 0                                   86             General Manager
# 1                                   69         Structural Engineer
# 2                                   10      Senior Cost Accountant
# 3                                   64  Account Representative III
# 4                                   34           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  ...  \
# 0         Manufacturing      Mass Customer                  N      Yes  ...
# 1              Property      Mass Customer                  N       No  ...
# ...

# %% [markdown]
# #### We need to merge the Customer Demographic with the Customer Address table

# %%
# Merge dataframe using customer_Id column
customer_demographic = pd.merge(customer_demographic,customer_add,how='left',on='customer_id')

# %%
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 3            9       Mala       Lind  Female
# 4           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases                             job_title  \
# 0                                   93                   Executive Secretary
# 1                                   81                Administrative Officer
# 2                                   61                    Recruiting Manager
# 3                                   97  Business Systems Development Analyst
# 4                                   49               Senior Quality Engineer
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                  N      Yes
# 1    Financial Services      Mass Customer                  N      Yes
# ...

# %%
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2864 entries, 0 to 2863
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          2864 non-null   int64
#  1   first_name                           2864 non-null   object
#  2   last_name                            2779 non-null   object
#  3   gender                               2864 non-null   object
#  4   past_3_years_bike_related_purchases  2864 non-null   int64
#  5   job_title                            2864 non-null   object
#  6   job_industry_category                2864 non-null   object
#  7   wealth_segment                       2864 non-null   object
#  8   deceased_indicator                   2864 non-null   object
#  9   owns_car                             2864 non-null   object
#  10  tenure                               2864 non-null   float64
# ...

# %%
new_customer_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 735 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          735 non-null    int64
#  1   first_name                           735 non-null    object
#  2   last_name                            715 non-null    object
#  3   gender                               735 non-null    object
#  4   past_3_years_bike_related_purchases  735 non-null    int64
#  5   job_title                            735 non-null    object
#  6   job_industry_category                735 non-null    object
#  7   wealth_segment                       735 non-null    object
#  8   deceased_indicator                   735 non-null    object
#  9   owns_car                             735 non-null    object
#  10  tenure                               735 non-null    int64
# ...

# %%
new_customer_details = pd.concat([customer_demographic,new_customer_lists], ignore_index=True, sort=False)

# %%
customer_demographic = new_customer_details

# %%
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 3            9       Mala       Lind  Female
# 4           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases                             job_title  \
# 0                                   93                   Executive Secretary
# 1                                   81                Administrative Officer
# 2                                   61                    Recruiting Manager
# 3                                   97  Business Systems Development Analyst
# 4                                   49               Senior Quality Engineer
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  ...  \
# 0                Health      Mass Customer                  N      Yes  ...
# ...

# %%
filepath = '/Users/riddhi/Documents/DS/KPMG/RIDDHI/Module -1 /Final_data.xlsx'
customer_demographic.to_excel(filepath,index = False)

# %% [markdown]
# #### Merge Transction dataframe with customer demographic dataframe to make a one single dataframe

# %%
transaction_existing_customer = transactions

# %%
transaction_existing_customer = pd.merge(transaction_existing_customer,customer_demographic[['customer_id','gender']],on='customer_id',how='left')

# %%
transaction_existing_customer.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               2           3         3120       2017-05-21           1.0
# 1               5          78          787       2017-10-01           1.0
# 2               6          25         2339       2017-03-08           1.0
# 3               7          22         1542       2017-04-21           1.0
# 4              10          12         3262       2017-08-30           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved   Trek Bicycles     Standard        medium        large
# 1     Approved  Giant Bicycles     Standard        medium        large
# 2     Approved  Giant Bicycles         Road        medium       medium
# 3     Approved        WeareA2B     Standard        medium       medium
# 4     Approved        WeareA2B     Standard        medium       medium
#
#    list_price  standard_cost product_first_sold_date   profit  gender
# ...

# %%
transaction_existing_customer = pd.merge(transaction_existing_customer,customer_demographic,on='customer_id',how='left')

# %%
transaction_existing_customer.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               2           3         3120       2017-05-21           1.0
# 1               5          78          787       2017-10-01           1.0
# 2               6          25         2339       2017-03-08           1.0
# 3               7          22         1542       2017-04-21           1.0
# 4              10          12         3262       2017-08-30           1.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved   Trek Bicycles     Standard        medium        large  ...
# 1     Approved  Giant Bicycles     Standard        medium        large  ...
# 2     Approved  Giant Bicycles         Road        medium       medium  ...
# 3     Approved        WeareA2B     Standard        medium       medium  ...
# 4     Approved        WeareA2B     Standard        medium       medium  ...
#
# ...

# %%
transaction_existing_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9739 entries, 0 to 9738
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction_id                       9739 non-null   int64
#  1   product_id                           9739 non-null   int64
#  2   customer_id                          9739 non-null   int64
#  3   transaction_date                     9739 non-null   datetime64[ns]
#  4   online_order                         9739 non-null   float64
#  5   order_status                         9739 non-null   object
#  6   brand                                9739 non-null   object
#  7   product_line                         9739 non-null   object
#  8   product_class                        9739 non-null   object
#  9   product_size                         9739 non-null   object
#  10  list_price                           9739 non-null   float64
# ...

# %%
transaction_existing_customer.drop(['gender_x'],axis=1,inplace=True)

# %%
Existing_Customer_Demographic = transaction_existing_customer

# %%
Existing_Customer_Demographic
# Out:
#       transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                  2           3         3120       2017-05-21           1.0
# 1                  5          78          787       2017-10-01           1.0
# 2                  6          25         2339       2017-03-08           1.0
# 3                  7          22         1542       2017-04-21           1.0
# 4                 10          12         3262       2017-08-30           1.0
# ...              ...         ...          ...              ...           ...
# 9734           19995           9          718       2017-05-13           1.0
# 9735           19996          51         1018       2017-06-24           1.0
# 9736           19997          41          127       2017-11-09           1.0
# 9737           19998          87         2284       2017-04-14           1.0
# 9738           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
file_path = '/Users/riddhi/Documents/DS/KPMG/RIDDHI/Module -1 /Final_data.xlsx'
Existing_Customer_Demographic.to_excel(file_path,index=False)

# %% [markdown]
# # Conclusion:

# %% [markdown]
# #### The given data is analysed and investigated in all aspects to inspect the Quality of data with respect to all qualities mentioned in the Data Quality Framework Table

# %% [markdown]
# - Accuracy
# - Completeness
# - Uniqueness
# - Validity
# - Consistency
# - Relevancy
# - Timeliness
